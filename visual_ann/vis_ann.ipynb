# %% [markdown]
# # 視覺化標註結果

# %%
from visual_img_ann import visualize_yolo_segmentation_annotations

label_map = {0: "cow"}
image_path = "../tmp_dataset/for_segment/yolo_data/images/3/eeba576d-000222.jpg"
annotation_path = "../tmp_dataset/for_segment/yolo_data/labels/3/eeba576d-000222.txt"

visualize_yolo_segmentation_annotations(
    image_path=image_path,
    annotation_path=annotation_path,
    label_map=label_map,
    save_path="visual_result/result.png"  
)
# Out:
# 載入標註檔案: ../tmp_dataset/for_segment/yolo_data/labels/3/eeba576d-000222.txt
# 發現 1 個標註物件
#   物件 1: cow (類別ID: 0)
#     多邊形頂點數: 934
#     邊界框: (0, 333, 369, 565)
# 結果已儲存至: visual_result/result.png
# (array([[[251, 251, 251],
#          [251, 251, 251],
#          [251, 251, 251],
#          ...,
#          [ 81,  77,  68],
#          [ 79,  76,  69],
#          [ 79,  76,  69]],
#
#         [[251, 251, 251],
#          [251, 251, 251],
#          [251, 251, 251],
#          ...,
#          [ 79,  75,  66],
#          [ 76,  73,  66],
#          [ 76,  73,  66]],
#
#         [[251, 251, 251],
#          [251, 251, 251],
#          [251, 251, 251],
#          ...,
#          [ 76,  72,  63],
#          [ 73,  70,  63],
#          [ 73,  70,  63]],
#
#         ...,
#
#         [[149, 184, 224],
#          [148, 183, 223],
#          [149, 184, 224],
#          ...,
#          [ 63,  67,  68],
#          [ 60,  64,  65],
#          [ 60,  64,  65]],
#
#         [[149, 184, 224],
# ...
